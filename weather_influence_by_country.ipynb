# %% [markdown]
# ## EDA (Explanatory Data Analysis)
# - ND-Gain Country Index: 기후의 취약성 + 적용역량 국가별 점수 (1995 ~ Current)
# - Climate Risk Index: 기상재해 피 해순위 (사망자, 경제적 손실)
# - World Risk Index : 자연재해 노출도, 취약성, 대응능력
# - EMDAT: 1990 ~ Current 자연 재해 Event 데이터
#
# ## API (Application Programming Interface)
# 1. url 접근을 Webserver 에 요청 (통신 방법=protocols)
# 2. Data 를 json, xml, csv 파일로 받아.
#
# ### json, xml, csv
# - csv: 기준으로 Parsing 한다고 보면 돼
# ```
# import requests
#
# url = ""
# response = requests.get(url)
# ```
#
# ### Python Package 를 관리하는 pip
# - numpy, pandas,,,,,, -> version 달라 (Python 버전)
# - 가상환경을 만들어서 관리를 해야돼

# %%
# !pip install pandas
# !pip install kaggle
# Out:
# ...
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kaggle]
#    ---------------------------------------- 2/2 [kaggle]
#
# ...

# %%
# !mkdir ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# The syntax of the command is incorrect.
# 'mv' is not recognized as an internal or external command,
# operable program or batch file.
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
